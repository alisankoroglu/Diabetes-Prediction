# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd 
import statsmodels.api as sm
import statsmodels.formula.api as smf
import seaborn as sns
from sklearn.preprocessing import scale 
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, cross_val_predict
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, log_loss
from sklearn.metrics import roc_auc_score,roc_curve
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# # Loading Dataset

# %% [markdown]
# **Pima Indian Diabetes Dataset Overview**
# * The Pima Indian Diabetes Dataset (PIDD) is a well-known dataset used in machine learning and statistical analysis for diabetes prediction. It was originally collected by the National Institute of Diabetes and Digestive and Kidney Diseases (NIDDK) and is widely used for binary classification tasks, particularly in medical and healthcare-related machine learning applications.

# %%
diabetes = pd.read_csv("pima indians diabetes dataset.csv")
df = diabetes.copy()
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
df.info() # structural information of the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# * Some measurements in the dataset have zero values.
# * Glucose, BloodPressure, SkinThickness, Insulin, BMI variables cannot have zero values.
# * Therefor, it is important to fill in these zero values.

# %%
(df == 0).sum()
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %% [markdown]
# * "It is understood that the dataset is imbalanced."

# %%
df["Outcome"].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
df["Outcome"].value_counts().plot.barh();

# %%
df.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    30.5000  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00
# Outcome                     0.0000    1.00000    1.00

# %%
sns.pairplot(df, hue = "Outcome")
plt.show()

# %%
def plot_correlation_heatmap(df):
    corr_matrix = df.corr()
    plt.figure(figsize = (10,8))
    sns.heatmap(corr_matrix, annot = True, cmap = "coolwarm", fmt = ".2f", linewidths = 0.5) 
    plt.title("Correlation of Features")
    plt.show()

# %%
plot_correlation_heatmap(df)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## KNN Imputation

# %%
from sklearn.impute import KNNImputer
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Columns where 0 values will be considered as missing values.
columns_to_replace = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

# Replace 0 values with NaN.
for col in columns_to_replace:
    df[col] = df[col].replace(0, np.nan)

# To drop rows where any of the specified columns contain 0 value
cleaned_df = df.dropna(subset=columns_to_replace)

# To fill missing values using the K-Nearest Neighbors (KNN) algorithmma
knn_imputer = KNNImputer(n_neighbors=5)
df_knn_filled = pd.DataFrame(knn_imputer.fit_transform(df), columns=df.columns)

# %%
sns.pairplot(df_knn_filled[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'Outcome']], hue="Outcome")
plt.show()

# %%
(df_knn_filled == 0).sum()
# Out:
# Pregnancies                 111
# Glucose                       0
# BloodPressure                 0
# SkinThickness                 0
# Insulin                       0
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
df_knn_filled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    float64
#  1   Glucose                   768 non-null    float64
#  2   BloodPressure             768 non-null    float64
#  3   SkinThickness             768 non-null    float64
#  4   Insulin                   768 non-null    float64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    float64
#  8   Outcome                   768 non-null    float64
# dtypes: float64(9)
# memory usage: 54.1 KB

# %%
df = df_knn_filled

# %% [markdown]
# ## Train-Test Split

# %%
y = df["Outcome"]
X = df.drop(["Outcome"], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %% [markdown]
# # Machine Learning Algorithms

# %% [markdown]
# ## Logistic Regression

# %%
loj = LogisticRegression(solver = "liblinear")
loj_model = loj.fit(X_train,y_train)

cross_val_score(loj_model, X_test, y_test, cv = 10).mean() # doğrulanmış ortalama hata
# Out:
# 0.7658333333333334

# %% [markdown]
# ## Naive Bayes (Gaussian)

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()
nb_model = nb.fit(X_train, y_train)

cross_val_score(nb_model, X_test, y_test, cv = 10).mean()
# Out:
# 0.7604166666666666

# %% [markdown]
# ## K-Nearest Neighbor (KNN)

# %%
knn_params = {"n_neighbors": np.arange(1,50)}

knn = KNeighborsClassifier()
knn_cv = GridSearchCV(knn, knn_params, cv=10)
knn_cv.fit(X_train, y_train)

print("The Best skor:" + str(knn_cv.best_score_))
print("The best parameters: " + str(knn_cv.best_params_))
# Out:
# The Best skor:0.7574828133262825
# The best parameters: {'n_neighbors': 19}

# %%
# Fine-tuned model
knn = KNeighborsClassifier(19)
knn_tuned = knn.fit(X_train, y_train)

knn_tuned.score(X_test, y_test)
# Out:
# 0.7142857142857143

# %% [markdown]
# ## Support Vector Classification (SVC)

# %%
svc_params = {"C": np.arange(1,10)}

svc = SVC(kernel = "linear")

svc_cv_model = GridSearchCV(svc,svc_params, 
                            cv = 10, 
                            n_jobs = -1, 
                            verbose = 2 )

svc_cv_model.fit(X_train, y_train)

print("The best parameters: " + str(svc_cv_model.best_params_))
# Out:
# Fitting 10 folds for each of 9 candidates, totalling 90 fits
# The best parameters: {'C': 4}

# %%
# Fine-tuned model
svc_tuned = SVC(kernel = "linear", C = 4).fit(X_train, y_train)

y_pred = svc_tuned.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7727272727272727

# %% [markdown]
# ## SVC - Radial Basis Function (RBF)

# %%
svc_params = {"C": [0.0001, 0.001, 0.1, 1, 5, 10 ,50 ,100],
             "gamma": [0.0001, 0.001, 0.1, 1, 5, 10 ,50 ,100]}

svc = SVC()
svc_cv_model = GridSearchCV(svc, svc_params, 
                         cv = 10, 
                         n_jobs = -1,
                         verbose = 2)

svc_cv_model.fit(X_train, y_train)

print("The best parameters: " + str(svc_cv_model.best_params_))
# Out:
# Fitting 10 folds for each of 64 candidates, totalling 640 fits
# The best parameters: {'C': 5, 'gamma': 0.0001}

# %%
# Fine-tuned modell
svc_tuned = SVC(C = 5, gamma = 0.0001).fit(X_train, y_train)

y_pred = svc_tuned.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7467532467532467

# %% [markdown]
# ## Artificial Neural Network (ANN)

# %%
# Standardization 
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# ANN Model
from sklearn.neural_network import MLPClassifier

# parameters to be tuned
mlpc_params = {"alpha": [0.1, 0.01, 0.02, 0.005, 0.0001,0.00001],
              "hidden_layer_sizes": [(10,10,10),
                                     (100,100,100),
                                     (100,100),
                                     (3,5), 
                                     (5, 3)],
              "solver" : ["lbfgs","adam","sgd"],
              "activation": ["relu","logistic"]}

# Model tuning
mlpc = MLPClassifier()
mlpc_cv_model = GridSearchCV(mlpc, mlpc_params, 
                         cv = 10, 
                         n_jobs = -1,
                         verbose = 2)

mlpc_cv_model.fit(X_train_scaled, y_train)

print("The best parameters: " + str(mlpc_cv_model.best_params_))
# Out:
# Fitting 10 folds for each of 180 candidates, totalling 1800 fits
# The best parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'solver': 'adam'}

# %%
# Fine-tuned model
mlpc_tuned = MLPClassifier(activation = "relu", 
                           alpha = 0.001, 
                           hidden_layer_sizes = (10, 10, 10),
                          solver = "adam")

mlpc_tuned.fit(X_train_scaled, y_train)

y_pred = mlpc_tuned.predict(X_test_scaled)
accuracy_score(y_test, y_pred)
# Out:
# 0.7597402597402597

# %% [markdown]
# ## Classification and Regression Trees (CART)

# %%
from sklearn.tree import DecisionTreeClassifier

# parameters to be tuned
cart_grid = {"max_depth": range(1,10),
            "min_samples_split" : list(range(2,50)) }

# Model tuning 
cart = tree.DecisionTreeClassifier()
cart_cv = GridSearchCV(cart, cart_grid, cv = 10, n_jobs = -1, verbose = 2)
cart_cv_model = cart_cv.fit(X_train, y_train)

print("The best parameters: " + str(cart_cv_model.best_params_))
# Out:
# Fitting 10 folds for each of 432 candidates, totalling 4320 fits
# The best parameters: {'max_depth': 2, 'min_samples_split': 2}

# %%
# Fine-tuned model
cart = tree.DecisionTreeClassifier(max_depth = 2, min_samples_split = 2)
cart_tuned = cart.fit(X_train, y_train)

y_pred = cart_tuned.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7727272727272727

# %% [markdown]
# ## Random Forests (RF)

# %%
from sklearn.ensemble import RandomForestClassifier

# parameters to be tuned
rf_params = {"max_depth":[2,5,8,10],
            "max_features": [2,5,8],
            "n_estimators": [10,500,1000],
            "min_samples_split": [2,5,10]}

# Model tuning 
rf_model = RandomForestClassifier()
rf_cv_model = GridSearchCV(rf_model,
                           rf_params,
                           cv = 10,
                           n_jobs = -1,
                           verbose = 2)

rf_cv_model.fit(X_train, y_train)

print("The best parameters: " + str(rf_cv_model.best_params_))
# Out:
# Fitting 10 folds for each of 108 candidates, totalling 1080 fits
# The best parameters: {'max_depth': 2, 'max_features': 2, 'min_samples_split': 2, 'n_estimators': 1000}

# %%
# Fine-tuned model
rf_tuned = RandomForestClassifier(max_depth = 2,
                                  max_features = 2,
                                  min_samples_split = 2,
                                  n_estimators = 1000)

rf_tuned.fit(X_train, y_train)

y_pred = rf_tuned.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7727272727272727

# %%
# To determine the importance of variables (feature importance)
Importance = pd.DataFrame({"Importance": rf_tuned.feature_importances_*100},
                         index = X_train.columns)

Importance.sort_values(by = "Importance", 
                       axis = 0, 
                       ascending = True).plot(kind ="barh", color = "r")

plt.xlabel("importance of variables")
# Out:
# Text(0.5, 0, 'importance of variables')

# %% [markdown]
# ## Gradient Boosting Machine (GBM)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# parameters to be tuned
gbm_params = {"learning_rate": [0.001, 0.01, 0.1, 0.05],
              "n_estimators": [10,500,1000],
              "max_depth":[2,5,8,10],
              "min_samples_split": [2,5,10]}

# Model tuning
gbm = GradientBoostingClassifier()
gbm_cv = GridSearchCV(gbm, gbm_params, cv = 10, n_jobs = -1, verbose = 2)
gbm_cv.fit(X_train, y_train)

print("The best parameters: " + str(gbm_cv.best_params_))
# Out:
# Fitting 10 folds for each of 144 candidates, totalling 1440 fits
# The best parameters: {'learning_rate': 0.01, 'max_depth': 2, 'min_samples_split': 2, 'n_estimators': 500}

# %%
# Fine-tuned model
gbm = GradientBoostingClassifier(learning_rate = 0.01,
                                 max_depth = 2,
                                 min_samples_split = 2,
                                 n_estimators = 500)

gbm_tuned = gbm.fit(X_train, y_train)

y_pred = gbm_tuned.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7662337662337663

# %% [markdown]
# ## XGBoost

# %%
# !pip install xgboost
from xgboost import XGBClassifier

# parameters to be tuned
xgb_params = {"learning_rate": [0.1, 0.01, 0.02, 0.05],
              "n_estimators": [100, 500, 1000, 2000],
              "max_depth": [3, 4, 5, 6],
              "min_samples_split": [2, 5, 10],
              "subsample": [0.6, 0.8, 1.0]}

# Model tuning
xgb = XGBClassifier()
xgb_cv = GridSearchCV(xgb, xgb_params, cv = 10, n_jobs = -1, verbose = 2)
xgb_cv.fit(X_train, y_train)

print("The best parameters: " + str(xgb_cv.best_params_))
# Out:
# Fitting 10 folds for each of 576 candidates, totalling 5760 fits
# The best parameters: {'learning_rate': 0.01, 'max_depth': 3, 'min_samples_split': 2, 'n_estimators': 500, 'subsample': 0.6}

# %%
# Fine-tuned model
xgb = XGBClassifier(learning_rate = 0.01,
                    max_depth = 3,
                    min_samples_split = 2,
                    n_estimators = 500,
                    subsample = 0.6)

xgb_tuned = xgb.fit(X_train, y_train)

y_pred = xgb_tuned.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7337662337662337

# %% [markdown]
# ## LightGBM

# %%
# !conda install -c conda-forge lightgbm
from lightgbm import LGBMClassifier

# parameters to be tuned
lgbm_params = {"learning_rate": [0.1, 0.01, 0.02, 0.05],
              "n_estimators": [100, 500, 1000, 2000],
              "max_depth": [3, 4, 5, 6],
              "min_child_samples": [5, 10, 20],
              "subsample": [0.6, 0.8, 1.0]}

# Model tuning
lgbm = LGBMClassifier()
lgbm_cv = GridSearchCV(lgbm, lgbm_params, cv = 10, n_jobs = -1, verbose = 2)
lgbm_cv.fit(X_train, y_train)

print("The best parameters: " + str(lgbm_cv.best_params_))
# Out:
# Fitting 10 folds for each of 576 candidates, totalling 5760 fits
# [LightGBM] [Info] Number of positive: 213, number of negative: 401
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000141 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 821
# [LightGBM] [Info] Number of data points in the train set: 614, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.346906 -> initscore=-0.632669
# [LightGBM] [Info] Start training from score -0.632669
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# The best parameters: {'learning_rate': 0.02, 'max_depth': 3, 'min_child_samples': 10, 'n_estimators': 100, 'subsample': 0.6}

# %%
# Fine-tuned model
lgbm = LGBMClassifier(learning_rate = 0.02,
                    max_depth = 3,
                    min_child_samples = 10,
                    n_estimators = 100,
                    subsample = 0.6)

lgbm_tuned = lgbm.fit(X_train, y_train)

y_pred = lgbm_tuned.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# [LightGBM] [Info] Number of positive: 213, number of negative: 401
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000869 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 821
# [LightGBM] [Info] Number of data points in the train set: 614, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.346906 -> initscore=-0.632669
# [LightGBM] [Info] Start training from score -0.632669
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 0.7662337662337663

# %% [markdown]
# ## CatBoost

# %%
# !pip install catboost
from catboost import CatBoostClassifier

catb_params = { "iterations":[200,500],
                "learning_rate":[0.01, 0.05, 0.1],
                "depth" : [3, 5, 8]}

catb = CatBoostClassifier()
catb_cv_model = GridSearchCV(catb, catb_params, cv=5, n_jobs = -1, verbose = 2)
catb_cv_model.fit(X_train, y_train)

catb_cv_model.best_params_
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# 0:	learn: 0.6379217	total: 136ms	remaining: 27.1s
# 1:	learn: 0.6007783	total: 139ms	remaining: 13.7s
# 2:	learn: 0.5672505	total: 141ms	remaining: 9.26s
# 3:	learn: 0.5506978	total: 143ms	remaining: 7.01s
# 4:	learn: 0.5265226	total: 145ms	remaining: 5.66s
# 5:	learn: 0.5109918	total: 147ms	remaining: 4.76s
# 6:	learn: 0.4944081	total: 150ms	remaining: 4.12s
# 7:	learn: 0.4818861	total: 152ms	remaining: 3.65s
# 8:	learn: 0.4643249	total: 154ms	remaining: 3.28s
# 9:	learn: 0.4539428	total: 157ms	remaining: 2.98s
# 10:	learn: 0.4447845	total: 159ms	remaining: 2.73s
# 11:	learn: 0.4346493	total: 161ms	remaining: 2.52s
# 12:	learn: 0.4247338	total: 163ms	remaining: 2.35s
# 13:	learn: 0.4176127	total: 165ms	remaining: 2.2s
# 14:	learn: 0.4102875	total: 168ms	remaining: 2.07s
# 15:	learn: 0.4066013	total: 170ms	remaining: 1.95s
# 16:	learn: 0.4024049	total: 172ms	remaining: 1.85s
# 17:	learn: 0.3982739	total: 174ms	remaining: 1.76s
# 18:	learn: 0.3938370	total: 176ms	remaining: 1.68s
# 19:	learn: 0.3914625	total: 178ms	remaining: 1.6s
# 20:	learn: 0.3880838	total: 181ms	remaining: 1.54s
# 21:	learn: 0.3844962	total: 183ms	remaining: 1.48s
# 22:	learn: 0.3816385	total: 185ms	remaining: 1.42s
# 23:	learn: 0.3788217	total: 187ms	remaining: 1.37s
# 24:	learn: 0.3763696	total: 189ms	remaining: 1.32s
# 25:	learn: 0.3731266	total: 191ms	remaining: 1.28s
# 26:	learn: 0.3704581	total: 193ms	remaining: 1.24s
# 27:	learn: 0.3648716	total: 195ms	remaining: 1.2s
# 28:	learn: 0.3636768	total: 197ms	remaining: 1.16s
# 29:	learn: 0.3618716	total: 199ms	remaining: 1.13s
# 30:	learn: 0.3590481	total: 201ms	remaining: 1.1s
# 31:	learn: 0.3573089	total: 203ms	remaining: 1.07s
# 32:	learn: 0.3545089	total: 205ms	remaining: 1.04s
# 33:	learn: 0.3534945	total: 207ms	remaining: 1.01s
# 34:	learn: 0.3514667	total: 209ms	remaining: 986ms
# 35:	learn: 0.3468441	total: 211ms	remaining: 963ms
# 36:	learn: 0.3450183	total: 214ms	remaining: 941ms
# 37:	learn: 0.3420481	total: 216ms	remaining: 920ms
# 38:	learn: 0.3384651	total: 218ms	remaining: 899ms
# 39:	learn: 0.3365581	total: 220ms	remaining: 879ms
# 40:	learn: 0.3336889	total: 222ms	remaining: 860ms
# 41:	learn: 0.3319288	total: 224ms	remaining: 841ms
# 42:	learn: 0.3302007	total: 226ms	remaining: 824ms
# 43:	learn: 0.3284501	total: 228ms	remaining: 809ms
# 44:	learn: 0.3264481	total: 230ms	remaining: 793ms
# 45:	learn: 0.3236319	total: 232ms	remaining: 778ms
# 46:	learn: 0.3206452	total: 234ms	remaining: 763ms
# 47:	learn: 0.3183477	total: 236ms	remaining: 748ms
# 48:	learn: 0.3154042	total: 238ms	remaining: 735ms
# 49:	learn: 0.3136607	total: 240ms	remaining: 721ms
# 50:	learn: 0.3099664	total: 242ms	remaining: 708ms
# 51:	learn: 0.3085832	total: 245ms	remaining: 696ms
# 52:	learn: 0.3073506	total: 247ms	remaining: 685ms
# 53:	learn: 0.3048887	total: 249ms	remaining: 673ms
# 54:	learn: 0.3029424	total: 251ms	remaining: 662ms
# 55:	learn: 0.2996108	total: 253ms	remaining: 651ms
# 56:	learn: 0.2977333	total: 255ms	remaining: 640ms
# 57:	learn: 0.2961156	total: 258ms	remaining: 631ms
# 58:	learn: 0.2949919	total: 260ms	remaining: 621ms
# 59:	learn: 0.2942670	total: 262ms	remaining: 611ms
# 60:	learn: 0.2923071	total: 264ms	remaining: 602ms
# 61:	learn: 0.2893559	total: 266ms	remaining: 592ms
# 62:	learn: 0.2862643	total: 268ms	remaining: 583ms
# 63:	learn: 0.2835929	total: 270ms	remaining: 574ms
# 64:	learn: 0.2819387	total: 272ms	remaining: 566ms
# 65:	learn: 0.2781307	total: 274ms	remaining: 557ms
# 66:	learn: 0.2765070	total: 276ms	remaining: 549ms
# 67:	learn: 0.2744769	total: 278ms	remaining: 540ms
# 68:	learn: 0.2718371	total: 280ms	remaining: 532ms
# 69:	learn: 0.2689757	total: 282ms	remaining: 525ms
# 70:	learn: 0.2662913	total: 284ms	remaining: 517ms
# 71:	learn: 0.2634862	total: 286ms	remaining: 509ms
# 72:	learn: 0.2614671	total: 288ms	remaining: 502ms
# 73:	learn: 0.2588461	total: 290ms	remaining: 494ms
# 74:	learn: 0.2584349	total: 292ms	remaining: 487ms
# 75:	learn: 0.2567312	total: 294ms	remaining: 480ms
# 76:	learn: 0.2541541	total: 296ms	remaining: 473ms
# 77:	learn: 0.2521430	total: 298ms	remaining: 466ms
# 78:	learn: 0.2508038	total: 300ms	remaining: 459ms
# 79:	learn: 0.2486055	total: 302ms	remaining: 453ms
# 80:	learn: 0.2472189	total: 304ms	remaining: 447ms
# 81:	learn: 0.2454322	total: 306ms	remaining: 441ms
# 82:	learn: 0.2438012	total: 308ms	remaining: 435ms
# 83:	learn: 0.2420647	total: 310ms	remaining: 429ms
# 84:	learn: 0.2403073	total: 312ms	remaining: 423ms
# 85:	learn: 0.2389104	total: 315ms	remaining: 417ms
# 86:	learn: 0.2375210	total: 318ms	remaining: 413ms
# 87:	learn: 0.2347546	total: 320ms	remaining: 407ms
# 88:	learn: 0.2335705	total: 322ms	remaining: 401ms
# 89:	learn: 0.2314796	total: 324ms	remaining: 396ms
# 90:	learn: 0.2311067	total: 326ms	remaining: 390ms
# 91:	learn: 0.2294218	total: 328ms	remaining: 385ms
# 92:	learn: 0.2256951	total: 330ms	remaining: 379ms
# 93:	learn: 0.2242348	total: 332ms	remaining: 375ms
# 94:	learn: 0.2230876	total: 335ms	remaining: 370ms
# 95:	learn: 0.2214518	total: 337ms	remaining: 365ms
# 96:	learn: 0.2185412	total: 339ms	remaining: 360ms
# 97:	learn: 0.2174751	total: 341ms	remaining: 355ms
# 98:	learn: 0.2157180	total: 343ms	remaining: 350ms
# 99:	learn: 0.2136119	total: 345ms	remaining: 345ms
# 100:	learn: 0.2103136	total: 347ms	remaining: 340ms
# 101:	learn: 0.2086614	total: 349ms	remaining: 336ms
# 102:	learn: 0.2070639	total: 352ms	remaining: 331ms
# 103:	learn: 0.2042018	total: 354ms	remaining: 326ms
# 104:	learn: 0.2018135	total: 356ms	remaining: 322ms
# 105:	learn: 0.1994187	total: 358ms	remaining: 317ms
# 106:	learn: 0.1972968	total: 359ms	remaining: 312ms
# 107:	learn: 0.1967828	total: 361ms	remaining: 308ms
# 108:	learn: 0.1942802	total: 364ms	remaining: 304ms
# 109:	learn: 0.1932474	total: 366ms	remaining: 299ms
# 110:	learn: 0.1920856	total: 368ms	remaining: 295ms
# 111:	learn: 0.1905617	total: 370ms	remaining: 290ms
# 112:	learn: 0.1901317	total: 372ms	remaining: 286ms
# 113:	learn: 0.1869332	total: 374ms	remaining: 282ms
# 114:	learn: 0.1855288	total: 376ms	remaining: 278ms
# 115:	learn: 0.1839361	total: 378ms	remaining: 273ms
# 116:	learn: 0.1820970	total: 380ms	remaining: 269ms
# 117:	learn: 0.1798374	total: 382ms	remaining: 265ms
# 118:	learn: 0.1782128	total: 384ms	remaining: 261ms
# 119:	learn: 0.1762764	total: 386ms	remaining: 257ms
# 120:	learn: 0.1754375	total: 388ms	remaining: 253ms
# 121:	learn: 0.1733321	total: 390ms	remaining: 249ms
# 122:	learn: 0.1725214	total: 392ms	remaining: 245ms
# 123:	learn: 0.1716242	total: 394ms	remaining: 241ms
# 124:	learn: 0.1710365	total: 396ms	remaining: 238ms
# 125:	learn: 0.1695623	total: 398ms	remaining: 234ms
# 126:	learn: 0.1681793	total: 400ms	remaining: 230ms
# 127:	learn: 0.1664892	total: 403ms	remaining: 226ms
# 128:	learn: 0.1657893	total: 405ms	remaining: 223ms
# 129:	learn: 0.1637431	total: 407ms	remaining: 219ms
# 130:	learn: 0.1624896	total: 410ms	remaining: 216ms
# 131:	learn: 0.1615825	total: 413ms	remaining: 213ms
# 132:	learn: 0.1596132	total: 415ms	remaining: 209ms
# 133:	learn: 0.1586676	total: 417ms	remaining: 206ms
# 134:	learn: 0.1574790	total: 420ms	remaining: 202ms
# 135:	learn: 0.1567201	total: 422ms	remaining: 199ms
# 136:	learn: 0.1552994	total: 424ms	remaining: 195ms
# 137:	learn: 0.1544518	total: 427ms	remaining: 192ms
# 138:	learn: 0.1538485	total: 429ms	remaining: 188ms
# 139:	learn: 0.1532144	total: 431ms	remaining: 185ms
# 140:	learn: 0.1520238	total: 434ms	remaining: 181ms
# 141:	learn: 0.1505724	total: 436ms	remaining: 178ms
# 142:	learn: 0.1487416	total: 438ms	remaining: 175ms
# 143:	learn: 0.1474031	total: 441ms	remaining: 171ms
# 144:	learn: 0.1460109	total: 443ms	remaining: 168ms
# 145:	learn: 0.1444031	total: 445ms	remaining: 165ms
# 146:	learn: 0.1437607	total: 447ms	remaining: 161ms
# 147:	learn: 0.1431996	total: 449ms	remaining: 158ms
# 148:	learn: 0.1427522	total: 452ms	remaining: 155ms
# 149:	learn: 0.1418274	total: 454ms	remaining: 151ms
# 150:	learn: 0.1410697	total: 457ms	remaining: 148ms
# 151:	learn: 0.1393810	total: 459ms	remaining: 145ms
# 152:	learn: 0.1389677	total: 461ms	remaining: 142ms
# 153:	learn: 0.1386229	total: 463ms	remaining: 138ms
# 154:	learn: 0.1379664	total: 465ms	remaining: 135ms
# 155:	learn: 0.1370372	total: 468ms	remaining: 132ms
# 156:	learn: 0.1367554	total: 470ms	remaining: 129ms
# 157:	learn: 0.1351498	total: 472ms	remaining: 126ms
# 158:	learn: 0.1338199	total: 475ms	remaining: 122ms
# 159:	learn: 0.1336584	total: 477ms	remaining: 119ms
# 160:	learn: 0.1334276	total: 479ms	remaining: 116ms
# 161:	learn: 0.1331947	total: 481ms	remaining: 113ms
# 162:	learn: 0.1326614	total: 483ms	remaining: 110ms
# 163:	learn: 0.1314184	total: 485ms	remaining: 107ms
# 164:	learn: 0.1309818	total: 488ms	remaining: 103ms
# 165:	learn: 0.1297623	total: 490ms	remaining: 100ms
# 166:	learn: 0.1287810	total: 492ms	remaining: 97.2ms
# 167:	learn: 0.1273599	total: 494ms	remaining: 94.1ms
# 168:	learn: 0.1259863	total: 496ms	remaining: 91ms
# 169:	learn: 0.1254345	total: 498ms	remaining: 88ms
# 170:	learn: 0.1237808	total: 501ms	remaining: 84.9ms
# 171:	learn: 0.1226612	total: 503ms	remaining: 81.9ms
# 172:	learn: 0.1217682	total: 505ms	remaining: 78.8ms
# 173:	learn: 0.1204415	total: 507ms	remaining: 75.8ms
# 174:	learn: 0.1200629	total: 509ms	remaining: 72.8ms
# 175:	learn: 0.1197354	total: 512ms	remaining: 69.8ms
# 176:	learn: 0.1186875	total: 514ms	remaining: 66.8ms
# 177:	learn: 0.1185510	total: 516ms	remaining: 63.8ms
# 178:	learn: 0.1173386	total: 518ms	remaining: 60.8ms
# 179:	learn: 0.1172561	total: 521ms	remaining: 57.8ms
# 180:	learn: 0.1166474	total: 523ms	remaining: 54.9ms
# 181:	learn: 0.1158273	total: 525ms	remaining: 51.9ms
# 182:	learn: 0.1148033	total: 527ms	remaining: 48.9ms
# 183:	learn: 0.1133699	total: 529ms	remaining: 46ms
# 184:	learn: 0.1121904	total: 531ms	remaining: 43.1ms
# 185:	learn: 0.1110931	total: 534ms	remaining: 40.2ms
# 186:	learn: 0.1102672	total: 536ms	remaining: 37.3ms
# 187:	learn: 0.1093886	total: 538ms	remaining: 34.4ms
# 188:	learn: 0.1087795	total: 541ms	remaining: 31.5ms
# 189:	learn: 0.1079894	total: 543ms	remaining: 28.6ms
# 190:	learn: 0.1071397	total: 545ms	remaining: 25.7ms
# 191:	learn: 0.1069544	total: 548ms	remaining: 22.8ms
# 192:	learn: 0.1065090	total: 550ms	remaining: 19.9ms
# 193:	learn: 0.1058022	total: 552ms	remaining: 17.1ms
# 194:	learn: 0.1050637	total: 554ms	remaining: 14.2ms
# 195:	learn: 0.1042837	total: 556ms	remaining: 11.3ms
# 196:	learn: 0.1037371	total: 558ms	remaining: 8.5ms
# 197:	learn: 0.1031755	total: 560ms	remaining: 5.66ms
# 198:	learn: 0.1023445	total: 563ms	remaining: 2.83ms
# 199:	learn: 0.1016566	total: 565ms	remaining: 0us
# {'depth': 5, 'iterations': 200, 'learning_rate': 0.1}

# %%
# Fine-tuned model
catb_tuned = CatBoostClassifier(iterations = 200, 
                               learning_rate = 0.1, 
                               depth = 5)

catb_tuned = catb_tuned.fit(X_train,y_train)

y_pred = catb_tuned.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0:	learn: 0.6379217	total: 2.45ms	remaining: 488ms
# 1:	learn: 0.6007783	total: 4.77ms	remaining: 472ms
# 2:	learn: 0.5672505	total: 7.3ms	remaining: 480ms
# 3:	learn: 0.5506978	total: 9.67ms	remaining: 474ms
# 4:	learn: 0.5265226	total: 11.9ms	remaining: 465ms
# 5:	learn: 0.5109918	total: 14.2ms	remaining: 461ms
# 6:	learn: 0.4944081	total: 16.4ms	remaining: 451ms
# 7:	learn: 0.4818861	total: 18.7ms	remaining: 449ms
# 8:	learn: 0.4643249	total: 20.9ms	remaining: 443ms
# 9:	learn: 0.4539428	total: 23.1ms	remaining: 439ms
# 10:	learn: 0.4447845	total: 25.4ms	remaining: 437ms
# 11:	learn: 0.4346493	total: 27.5ms	remaining: 430ms
# 12:	learn: 0.4247338	total: 29.7ms	remaining: 427ms
# 13:	learn: 0.4176127	total: 32ms	remaining: 425ms
# 14:	learn: 0.4102875	total: 34.3ms	remaining: 423ms
# 15:	learn: 0.4066013	total: 36.4ms	remaining: 419ms
# 16:	learn: 0.4024049	total: 38.5ms	remaining: 414ms
# 17:	learn: 0.3982739	total: 40.6ms	remaining: 411ms
# 18:	learn: 0.3938370	total: 42.8ms	remaining: 407ms
# 19:	learn: 0.3914625	total: 44.8ms	remaining: 403ms
# 20:	learn: 0.3880838	total: 46.8ms	remaining: 399ms
# 21:	learn: 0.3844962	total: 48.8ms	remaining: 395ms
# 22:	learn: 0.3816385	total: 50.7ms	remaining: 390ms
# 23:	learn: 0.3788217	total: 53ms	remaining: 389ms
# 24:	learn: 0.3763696	total: 55.3ms	remaining: 387ms
# 25:	learn: 0.3731266	total: 57.5ms	remaining: 385ms
# 26:	learn: 0.3704581	total: 59.6ms	remaining: 382ms
# 27:	learn: 0.3648716	total: 61.6ms	remaining: 379ms
# 28:	learn: 0.3636768	total: 63.6ms	remaining: 375ms
# 29:	learn: 0.3618716	total: 65.5ms	remaining: 371ms
# 30:	learn: 0.3590481	total: 67.5ms	remaining: 368ms
# 31:	learn: 0.3573089	total: 69.7ms	remaining: 366ms
# 32:	learn: 0.3545089	total: 71.8ms	remaining: 363ms
# 33:	learn: 0.3534945	total: 73.9ms	remaining: 361ms
# 34:	learn: 0.3514667	total: 76ms	remaining: 358ms
# 35:	learn: 0.3468441	total: 78ms	remaining: 356ms
# 36:	learn: 0.3450183	total: 80.1ms	remaining: 353ms
# 37:	learn: 0.3420481	total: 82.1ms	remaining: 350ms
# 38:	learn: 0.3384651	total: 84.1ms	remaining: 347ms
# 39:	learn: 0.3365581	total: 86.1ms	remaining: 344ms
# 40:	learn: 0.3336889	total: 88.1ms	remaining: 342ms
# 41:	learn: 0.3319288	total: 90.2ms	remaining: 339ms
# 42:	learn: 0.3302007	total: 92.2ms	remaining: 337ms
# 43:	learn: 0.3284501	total: 94.2ms	remaining: 334ms
# 44:	learn: 0.3264481	total: 96.2ms	remaining: 331ms
# 45:	learn: 0.3236319	total: 98.2ms	remaining: 329ms
# 46:	learn: 0.3206452	total: 100ms	remaining: 327ms
# 47:	learn: 0.3183477	total: 102ms	remaining: 324ms
# 48:	learn: 0.3154042	total: 104ms	remaining: 322ms
# 49:	learn: 0.3136607	total: 107ms	remaining: 320ms
# 50:	learn: 0.3099664	total: 109ms	remaining: 317ms
# 51:	learn: 0.3085832	total: 111ms	remaining: 315ms
# 52:	learn: 0.3073506	total: 113ms	remaining: 313ms
# 53:	learn: 0.3048887	total: 115ms	remaining: 311ms
# 54:	learn: 0.3029424	total: 117ms	remaining: 309ms
# 55:	learn: 0.2996108	total: 119ms	remaining: 307ms
# 56:	learn: 0.2977333	total: 122ms	remaining: 305ms
# 57:	learn: 0.2961156	total: 124ms	remaining: 302ms
# 58:	learn: 0.2949919	total: 125ms	remaining: 300ms
# 59:	learn: 0.2942670	total: 127ms	remaining: 297ms
# 60:	learn: 0.2923071	total: 129ms	remaining: 295ms
# 61:	learn: 0.2893559	total: 132ms	remaining: 293ms
# 62:	learn: 0.2862643	total: 134ms	remaining: 291ms
# 63:	learn: 0.2835929	total: 136ms	remaining: 289ms
# 64:	learn: 0.2819387	total: 138ms	remaining: 287ms
# 65:	learn: 0.2781307	total: 140ms	remaining: 284ms
# 66:	learn: 0.2765070	total: 142ms	remaining: 282ms
# 67:	learn: 0.2744769	total: 144ms	remaining: 280ms
# 68:	learn: 0.2718371	total: 147ms	remaining: 278ms
# 69:	learn: 0.2689757	total: 149ms	remaining: 276ms
# 70:	learn: 0.2662913	total: 151ms	remaining: 274ms
# 71:	learn: 0.2634862	total: 153ms	remaining: 273ms
# 72:	learn: 0.2614671	total: 156ms	remaining: 271ms
# 73:	learn: 0.2588461	total: 158ms	remaining: 269ms
# 74:	learn: 0.2584349	total: 160ms	remaining: 267ms
# 75:	learn: 0.2567312	total: 162ms	remaining: 264ms
# 76:	learn: 0.2541541	total: 164ms	remaining: 263ms
# 77:	learn: 0.2521430	total: 167ms	remaining: 261ms
# 78:	learn: 0.2508038	total: 169ms	remaining: 259ms
# 79:	learn: 0.2486055	total: 172ms	remaining: 258ms
# 80:	learn: 0.2472189	total: 174ms	remaining: 255ms
# 81:	learn: 0.2454322	total: 176ms	remaining: 254ms
# 82:	learn: 0.2438012	total: 179ms	remaining: 252ms
# 83:	learn: 0.2420647	total: 181ms	remaining: 250ms
# 84:	learn: 0.2403073	total: 183ms	remaining: 248ms
# 85:	learn: 0.2389104	total: 186ms	remaining: 246ms
# 86:	learn: 0.2375210	total: 188ms	remaining: 244ms
# 87:	learn: 0.2347546	total: 190ms	remaining: 242ms
# 88:	learn: 0.2335705	total: 194ms	remaining: 241ms
# 89:	learn: 0.2314796	total: 196ms	remaining: 240ms
# 90:	learn: 0.2311067	total: 198ms	remaining: 237ms
# 91:	learn: 0.2294218	total: 201ms	remaining: 236ms
# 92:	learn: 0.2256951	total: 203ms	remaining: 233ms
# 93:	learn: 0.2242348	total: 205ms	remaining: 231ms
# 94:	learn: 0.2230876	total: 207ms	remaining: 229ms
# 95:	learn: 0.2214518	total: 209ms	remaining: 226ms
# 96:	learn: 0.2185412	total: 211ms	remaining: 224ms
# 97:	learn: 0.2174751	total: 213ms	remaining: 222ms
# 98:	learn: 0.2157180	total: 215ms	remaining: 219ms
# 99:	learn: 0.2136119	total: 217ms	remaining: 217ms
# 100:	learn: 0.2103136	total: 219ms	remaining: 215ms
# 101:	learn: 0.2086614	total: 221ms	remaining: 212ms
# 102:	learn: 0.2070639	total: 223ms	remaining: 210ms
# 103:	learn: 0.2042018	total: 225ms	remaining: 208ms
# 104:	learn: 0.2018135	total: 228ms	remaining: 206ms
# 105:	learn: 0.1994187	total: 230ms	remaining: 204ms
# 106:	learn: 0.1972968	total: 232ms	remaining: 202ms
# 107:	learn: 0.1967828	total: 235ms	remaining: 200ms
# 108:	learn: 0.1942802	total: 237ms	remaining: 198ms
# 109:	learn: 0.1932474	total: 239ms	remaining: 196ms
# 110:	learn: 0.1920856	total: 241ms	remaining: 194ms
# 111:	learn: 0.1905617	total: 244ms	remaining: 191ms
# 112:	learn: 0.1901317	total: 246ms	remaining: 189ms
# 113:	learn: 0.1869332	total: 248ms	remaining: 187ms
# 114:	learn: 0.1855288	total: 250ms	remaining: 185ms
# 115:	learn: 0.1839361	total: 252ms	remaining: 183ms
# 116:	learn: 0.1820970	total: 255ms	remaining: 181ms
# 117:	learn: 0.1798374	total: 257ms	remaining: 179ms
# 118:	learn: 0.1782128	total: 259ms	remaining: 177ms
# 119:	learn: 0.1762764	total: 262ms	remaining: 174ms
# 120:	learn: 0.1754375	total: 264ms	remaining: 172ms
# 121:	learn: 0.1733321	total: 267ms	remaining: 171ms
# 122:	learn: 0.1725214	total: 269ms	remaining: 168ms
# 123:	learn: 0.1716242	total: 271ms	remaining: 166ms
# 124:	learn: 0.1710365	total: 274ms	remaining: 164ms
# 125:	learn: 0.1695623	total: 276ms	remaining: 162ms
# 126:	learn: 0.1681793	total: 278ms	remaining: 160ms
# 127:	learn: 0.1664892	total: 280ms	remaining: 158ms
# 128:	learn: 0.1657893	total: 282ms	remaining: 155ms
# 129:	learn: 0.1637431	total: 285ms	remaining: 153ms
# 130:	learn: 0.1624896	total: 287ms	remaining: 151ms
# 131:	learn: 0.1615825	total: 289ms	remaining: 149ms
# 132:	learn: 0.1596132	total: 291ms	remaining: 147ms
# 133:	learn: 0.1586676	total: 293ms	remaining: 144ms
# 134:	learn: 0.1574790	total: 295ms	remaining: 142ms
# 135:	learn: 0.1567201	total: 297ms	remaining: 140ms
# 136:	learn: 0.1552994	total: 300ms	remaining: 138ms
# 137:	learn: 0.1544518	total: 302ms	remaining: 136ms
# 138:	learn: 0.1538485	total: 304ms	remaining: 134ms
# 139:	learn: 0.1532144	total: 307ms	remaining: 131ms
# 140:	learn: 0.1520238	total: 309ms	remaining: 129ms
# 141:	learn: 0.1505724	total: 311ms	remaining: 127ms
# 142:	learn: 0.1487416	total: 313ms	remaining: 125ms
# 143:	learn: 0.1474031	total: 316ms	remaining: 123ms
# 144:	learn: 0.1460109	total: 318ms	remaining: 120ms
# 145:	learn: 0.1444031	total: 320ms	remaining: 118ms
# 146:	learn: 0.1437607	total: 322ms	remaining: 116ms
# 147:	learn: 0.1431996	total: 324ms	remaining: 114ms
# 148:	learn: 0.1427522	total: 326ms	remaining: 112ms
# 149:	learn: 0.1418274	total: 329ms	remaining: 110ms
# 150:	learn: 0.1410697	total: 331ms	remaining: 107ms
# 151:	learn: 0.1393810	total: 333ms	remaining: 105ms
# 152:	learn: 0.1389677	total: 335ms	remaining: 103ms
# 153:	learn: 0.1386229	total: 337ms	remaining: 101ms
# 154:	learn: 0.1379664	total: 339ms	remaining: 98.5ms
# 155:	learn: 0.1370372	total: 341ms	remaining: 96.3ms
# 156:	learn: 0.1367554	total: 344ms	remaining: 94.1ms
# 157:	learn: 0.1351498	total: 346ms	remaining: 92ms
# 158:	learn: 0.1338199	total: 348ms	remaining: 89.8ms
# 159:	learn: 0.1336584	total: 350ms	remaining: 87.6ms
# 160:	learn: 0.1334276	total: 353ms	remaining: 85.4ms
# 161:	learn: 0.1331947	total: 355ms	remaining: 83.2ms
# 162:	learn: 0.1326614	total: 357ms	remaining: 81ms
# 163:	learn: 0.1314184	total: 359ms	remaining: 78.8ms
# 164:	learn: 0.1309818	total: 361ms	remaining: 76.6ms
# 165:	learn: 0.1297623	total: 363ms	remaining: 74.4ms
# 166:	learn: 0.1287810	total: 366ms	remaining: 72.3ms
# 167:	learn: 0.1273599	total: 368ms	remaining: 70.1ms
# 168:	learn: 0.1259863	total: 370ms	remaining: 67.9ms
# 169:	learn: 0.1254345	total: 372ms	remaining: 65.7ms
# 170:	learn: 0.1237808	total: 374ms	remaining: 63.5ms
# 171:	learn: 0.1226612	total: 377ms	remaining: 61.3ms
# 172:	learn: 0.1217682	total: 379ms	remaining: 59.1ms
# 173:	learn: 0.1204415	total: 381ms	remaining: 56.9ms
# 174:	learn: 0.1200629	total: 383ms	remaining: 54.7ms
# 175:	learn: 0.1197354	total: 385ms	remaining: 52.5ms
# 176:	learn: 0.1186875	total: 387ms	remaining: 50.3ms
# 177:	learn: 0.1185510	total: 389ms	remaining: 48.1ms
# 178:	learn: 0.1173386	total: 392ms	remaining: 46ms
# 179:	learn: 0.1172561	total: 394ms	remaining: 43.8ms
# 180:	learn: 0.1166474	total: 396ms	remaining: 41.6ms
# 181:	learn: 0.1158273	total: 398ms	remaining: 39.4ms
# 182:	learn: 0.1148033	total: 400ms	remaining: 37.2ms
# 183:	learn: 0.1133699	total: 403ms	remaining: 35ms
# 184:	learn: 0.1121904	total: 405ms	remaining: 32.8ms
# 185:	learn: 0.1110931	total: 407ms	remaining: 30.6ms
# 186:	learn: 0.1102672	total: 409ms	remaining: 28.4ms
# 187:	learn: 0.1093886	total: 411ms	remaining: 26.2ms
# 188:	learn: 0.1087795	total: 413ms	remaining: 24ms
# 189:	learn: 0.1079894	total: 415ms	remaining: 21.8ms
# 190:	learn: 0.1071397	total: 416ms	remaining: 19.6ms
# 191:	learn: 0.1069544	total: 418ms	remaining: 17.4ms
# 192:	learn: 0.1065090	total: 421ms	remaining: 15.3ms
# 193:	learn: 0.1058022	total: 423ms	remaining: 13.1ms
# 194:	learn: 0.1050637	total: 425ms	remaining: 10.9ms
# 195:	learn: 0.1042837	total: 427ms	remaining: 8.71ms
# 196:	learn: 0.1037371	total: 429ms	remaining: 6.54ms
# 197:	learn: 0.1031755	total: 431ms	remaining: 4.36ms
# 198:	learn: 0.1023445	total: 434ms	remaining: 2.18ms
# 199:	learn: 0.1016566	total: 436ms	remaining: 0us
# 0.7402597402597403

# %% [markdown]
# # Comparing The Performans of Machine Learning Models

# %%
modeller = [knn_tuned,
            loj_model,
            svc_tuned,
            nb_model,
            mlpc_tuned,
            cart_tuned,
            rf_tuned,
            gbm_tuned,
            catb_tuned,
            lgbm_tuned,
            xgb_tuned]

for model in modeller:
    names = model.__class__.__name__
    y_pred = model.predict(X_test)
    dogruluk = accuracy_score(y_test, y_pred)
    print("-"*28)
    print(names + ".")
    print("Accuracy: {:.4%}".format(dogruluk))
# Out:
# ----------------------------
# KNeighborsClassifier.
# Accuracy: 71.4286%
# ----------------------------
# LogisticRegression.
# Accuracy: 75.9740%
# ----------------------------
# SVC.
# Accuracy: 74.6753%
# ----------------------------
# GaussianNB.
# Accuracy: 74.0260%
# ----------------------------
# MLPClassifier.
# Accuracy: 35.7143%
# ----------------------------
# DecisionTreeClassifier.
# Accuracy: 77.2727%
# ----------------------------
# RandomForestClassifier.
# Accuracy: 77.2727%
# ----------------------------
# GradientBoostingClassifier.
# Accuracy: 76.6234%
# ----------------------------
# CatBoostClassifier.
# Accuracy: 74.0260%
# ----------------------------
# LGBMClassifier.
# Accuracy: 76.6234%
# ----------------------------
# XGBClassifier.
# Accuracy: 73.3766%

# %%
sonuc = []
sonuclar = pd.DataFrame(columns = ["Modeller", "Accuracy"])
for model in modeller:
    isimler = model.__class__.__name__
    y_pred = model.predict(X_test)
    dogruluk = accuracy_score(y_test, y_pred)
    sonuc = pd.DataFrame([[isimler, dogruluk*100]], columns = ["Modeller", "Accuracy"])
    sonuclar = sonuclar.append(sonuc)

sns.barplot(x = "Accuracy", y = "Models", data = sonuclar, color = "r")
plt.xlabel("Accuracy")
plt.title("Accuracy of the Models");
